# %% [markdown]
# Tools for missing data, duplicate data, string manipulation, and some other analytical data transformations.

# %% [markdown]
# ### Handling Missing Data
#
# All of the descriptive statistics on pandas objects exclude missing data by default. NaN is a *sentinel value* that can be easily detected.

# %%
import pandas as pd
import numpy as np

a_series = pd.Series(['artichoke', 'letucce', np.nan, 'cilantro'])

a_series
# Out:
# 0    artichoke
# 1      letucce
# 2          NaN
# 3     cilantro
# dtype: object

# %%
a_series.isnull()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# dtype: bool

# %% [markdown]
# When cleaning up data for analysis, it is often important to do analysis on the missing data itself to identify data collection problems or potential biases in the data caused by missing data.
#
# The built-in Python *None* value is also treated as NA in object arrays.
#
# dropna() removes the NA values.

# %%
a_series.dropna()
# Out:
# 0    artichoke
# 1      letucce
# 3     cilantro
# dtype: object

# %%
df = pd.DataFrame([[1, 4, 2, 8], 
                 ['asdf', np.nan, 'sdf', 'df'],
                 [9, 0, np.nan, 3]])

df
# Out:
#       0    1    2   3
# 0     1  4.0    2   8
# 1  asdf  NaN  sdf  df
# 2     9  0.0  NaN   3

# %%
cleaned = df.dropna() # in a DataFrame, dropna() drops the instances/rows with NaN

# %%
cleaned
# Out:
#    0    1  2  3
# 0  1  4.0  2  8

# %% [markdown]
# dropna(how='all') will only drop rows that are all NA.

# %%
df[2] = np.nan

# %%
df
# Out:
#       0    1   2   3
# 0     1  4.0 NaN   8
# 1  asdf  NaN NaN  df
# 2     9  0.0 NaN   3

# %%
df.dropna(how='all', axis=1) # will drop columns with all values NaN
# Out:
#       0    1   3
# 0     1  4.0   8
# 1  asdf  NaN  df
# 2     9  0.0   3

# %%
df2 = pd.DataFrame(np.random.randn(6, 7))

df2
# Out:
#           0         1         2         3         4         5         6
# 0 -0.052232  0.622271  0.913073  0.991239 -0.663992 -1.609501 -1.790384
# 1 -0.922147  0.077835 -1.170292 -0.759632 -0.321846  0.817847 -0.642239
# 2 -0.919701 -2.264835  0.076041 -0.243128  0.433749 -0.619012  0.317007
# 3  0.986940 -1.001859  0.899056  1.379279  0.241880 -1.571206 -0.501158
# 4  0.320348 -0.660196 -1.892148  1.822202  1.313109 -0.278788  0.655076
# 5  0.162260 -0.176792  0.094787 -2.543953  0.589935 -1.037856 -0.078592

# %%
df2.iloc[:4, 3] = np.nan

df2
# Out:
#           0         1         2         3         4         5         6
# 0 -0.052232  0.622271  0.913073       NaN -0.663992 -1.609501 -1.790384
# 1 -0.922147  0.077835 -1.170292       NaN -0.321846  0.817847 -0.642239
# 2 -0.919701 -2.264835  0.076041       NaN  0.433749 -0.619012  0.317007
# 3  0.986940 -1.001859  0.899056       NaN  0.241880 -1.571206 -0.501158
# 4  0.320348 -0.660196 -1.892148  1.822202       NaN       NaN       NaN
# 5  0.162260 -0.176792  0.094787 -2.543953       NaN       NaN       NaN

# %%
df2.iloc[3:, 4:] = np.nan

df2
# Out:
#           0         1         2         3         4         5         6
# 0 -0.052232  0.622271  0.913073       NaN -0.663992 -1.609501 -1.790384
# 1 -0.922147  0.077835 -1.170292       NaN -0.321846  0.817847 -0.642239
# 2 -0.919701 -2.264835  0.076041       NaN  0.433749 -0.619012  0.317007
# 3  0.986940 -1.001859  0.899056       NaN       NaN       NaN       NaN
# 4  0.320348 -0.660196 -1.892148  1.822202       NaN       NaN       NaN
# 5  0.162260 -0.176792  0.094787 -2.543953       NaN       NaN       NaN

# %%
df2.dropna()
# Out:
# Empty DataFrame
# Columns: [0, 1, 2, 3, 4, 5, 6]
# Index: []

# %%
df2.dropna(thresh=5)
# Out:
#           0         1         2   3         4         5         6
# 0 -0.052232  0.622271  0.913073 NaN -0.663992 -1.609501 -1.790384
# 1 -0.922147  0.077835 -1.170292 NaN -0.321846  0.817847 -0.642239
# 2 -0.919701 -2.264835  0.076041 NaN  0.433749 -0.619012  0.317007

# %% [markdown]
# Filling the missing values.

# %%
df2.fillna(2)
# Out:
#           0         1         2         3         4         5         6
# 0 -0.052232  0.622271  0.913073  2.000000 -0.663992 -1.609501 -1.790384
# 1 -0.922147  0.077835 -1.170292  2.000000 -0.321846  0.817847 -0.642239
# 2 -0.919701 -2.264835  0.076041  2.000000  0.433749 -0.619012  0.317007
# 3  0.986940 -1.001859  0.899056  2.000000  2.000000  2.000000  2.000000
# 4  0.320348 -0.660196 -1.892148  1.822202  2.000000  2.000000  2.000000
# 5  0.162260 -0.176792  0.094787 -2.543953  2.000000  2.000000  2.000000

# %% [markdown]
# Filling each column's NAs with different values.

# %%
df2.fillna({3: 6.8, 4: 0})
# Out:
#           0         1         2         3         4         5         6
# 0 -0.052232  0.622271  0.913073  6.800000 -0.663992 -1.609501 -1.790384
# 1 -0.922147  0.077835 -1.170292  6.800000 -0.321846  0.817847 -0.642239
# 2 -0.919701 -2.264835  0.076041  6.800000  0.433749 -0.619012  0.317007
# 3  0.986940 -1.001859  0.899056  6.800000  0.000000       NaN       NaN
# 4  0.320348 -0.660196 -1.892148  1.822202  0.000000       NaN       NaN
# 5  0.162260 -0.176792  0.094787 -2.543953  0.000000       NaN       NaN

# %% [markdown]
# fillna returns a new object, but we can modify the existing object in-place.

# %%
_ = df.fillna(1, inplace=True) # replacing NA in place

# %%
df
# Out:
#       0    1    2   3
# 0     1  4.0  1.0   8
# 1  asdf  1.0  1.0  df
# 2     9  0.0  1.0   3

# %%
df2.fillna(method='ffill')
# Out:
#           0         1         2         3         4         5         6
# 0 -0.052232  0.622271  0.913073       NaN -0.663992 -1.609501 -1.790384
# 1 -0.922147  0.077835 -1.170292       NaN -0.321846  0.817847 -0.642239
# 2 -0.919701 -2.264835  0.076041       NaN  0.433749 -0.619012  0.317007
# 3  0.986940 -1.001859  0.899056       NaN  0.433749 -0.619012  0.317007
# 4  0.320348 -0.660196 -1.892148  1.822202  0.433749 -0.619012  0.317007
# 5  0.162260 -0.176792  0.094787 -2.543953  0.433749 -0.619012  0.317007

# %% [markdown]
# ### Replacing Existing Data

# %%
data = pd.Series([1., -999., 2., -999., -1000., 3.])

data
# Out:
# 0       1.0
# 1    -999.0
# 2       2.0
# 3    -999.0
# 4   -1000.0
# 5       3.0
# dtype: float64

# %%
data.replace([-999, -1000], np.nan, inplace=True)  ##  or data.replace({-999: np.nan, -1000: 0})

data
# Out:
# 0    1.0
# 1    NaN
# 2    2.0
# 3    NaN
# 4    NaN
# 5    3.0
# dtype: float64

# %% [markdown]
# ### Renaming Axis Indexing

# %%
data = pd.DataFrame(np.arange(12).reshape((3, 4)),
       index=['Ohio', 'Colorado', 'New York'],
       columns=['one', 'two', 'three', 'four'])

data
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7
# New York    8    9     10    11

# %% [markdown]
# ### Merging datasets
#
# *pandas.merge* connects rows in DataFrames based on one or more keys. This is familiar to SQL or other relational databases, as it implements database join operations.
#
# pandas.concat concatenates or “stacks” together objects along an axis.
#
# The combine_first instance method enables splicing together overlapping data to fill in missing values in one object with values from another.

# %%
df1 = pd.DataFrame({'key': ['b', 'b', 'a', 'c', 'a', 'a', 'b'],
                   'data1': range(7)})

# %%
df2 = pd.DataFrame({'key': ['a', 'b', 'd'],
                   'data2': range(3)})

# %%
pd.merge(df1, df2)

# %%
pd.merge(df1, df2, on='key') # specifying to use column names as keys, which is also the default method
